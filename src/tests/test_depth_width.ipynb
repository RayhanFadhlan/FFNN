# %% [markdown]
# # Pengujian Pengaruh Depth dan Width pada FFNN

# %% [markdown]
# Pengujian betujuan untuk menganalisis pengaruh kedalaman jaringan (depth)
# dan lebar jaringan (width) terhadap performa model FFNN.

# %%
import os
import sys

import matplotlib.pyplot as plt

# Add parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %load_ext autoreload
# %autoreload 2

from activation import ReLU, Softmax
from loss import CategoricalCrossEntropy
from model import FFNN
from utils import load_mnist_data, train_and_evaluate

# Create out dir
os.makedirs("../../out", exist_ok=True)

# %%
# Load MNIST dataset
X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data(
    subset_size=10000
)

input_size = X_train.shape[1]  # 784 for MNIST
output_size = y_train_onehot.shape[1]  # 10 for MNIST

# Experiment configs
epochs = 10
batch_size = 32
learning_rate = 0.01
# Out:
# Loading MNIST dataset...
# Data loaded: X_train: (8000, 784), y_train: (8000,)
# Test data: X_test: (2000, 784), y_test: (2000,)

# %% [markdown]
# ## Experiment 1: Varying Width

# %%
# Testing 3 different widths with fixed depth
widths = [32, 64, 128]
width_histories = []
width_accuracies = []

for width in widths:
    model_name = f"FFNN (1 hidden layer, {width} neurons)"
    print(f"\nTraining model with width={width}")

    model = FFNN(
        layer_sizes=[input_size, width, output_size],
        activations=[ReLU(), Softmax()],
        loss=CategoricalCrossEntropy(),
    )

    history, accuracy, _, _ = train_and_evaluate(
        model,
        X_train,
        X_test,
        y_train_onehot,
        y_test,
        y_test_onehot,
        epochs=epochs,
        batch_size=batch_size,
        learning_rate=learning_rate,
        model_name=model_name,
    )

    width_histories.append(history)
    width_accuracies.append(accuracy)

# Plot width experiment results
plt.figure(figsize=(12, 6))
for i, width in enumerate(widths):
    plt.plot(width_histories[i]["loss"], label=f"Width={width}")

plt.title("Training Loss vs. Width (1 Hidden Layer)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.savefig("../../out/width_comparison_loss.png")

# Bar chart of accuracies
plt.figure(figsize=(10, 6))
plt.bar([str(w) for w in widths], width_accuracies, color="skyblue")
plt.title("Test Accuracy vs. Width (1 Hidden Layer)")
plt.xlabel("Width (neurons)")
plt.ylabel("Accuracy")
plt.ylim([0.9 * min(width_accuracies), 1.0])  # Adjust y-axis for better visibility
for i, v in enumerate(width_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha="center")
plt.savefig("../../out/width_comparison_accuracy.png")
# Out:
# Training model with width=32
#
# Training FFNN (1 hidden layer, 32 neurons)...
# Epoch 1/10: 100%|██████████| 250/250 [00:01<00:00, 186.47batch/s, loss=0.4179]
# Epoch 1/10 - loss: 0.4731, val_loss: 0.3586
# Epoch 2/10: 100%|██████████| 250/250 [00:01<00:00, 223.50batch/s, loss=0.2109]
# Epoch 2/10 - loss: 0.2423, val_loss: 0.2926
# Epoch 3/10: 100%|██████████| 250/250 [00:01<00:00, 201.67batch/s, loss=0.4355]
# Epoch 3/10 - loss: 0.1756, val_loss: 0.3367
# Epoch 4/10: 100%|██████████| 250/250 [00:01<00:00, 180.85batch/s, loss=0.0570]
# Epoch 4/10 - loss: 0.1454, val_loss: 0.2913
# Epoch 5/10: 100%|██████████| 250/250 [00:01<00:00, 175.41batch/s, loss=0.3383]
# Epoch 5/10 - loss: 0.1274, val_loss: 0.2857
# Epoch 6/10: 100%|██████████| 250/250 [00:01<00:00, 181.66batch/s, loss=0.1983]
# Epoch 6/10 - loss: 0.1093, val_loss: 0.3325
# Epoch 7/10: 100%|██████████| 250/250 [00:01<00:00, 167.34batch/s, loss=0.0423]
# Epoch 7/10 - loss: 0.0846, val_loss: 0.3112
# Epoch 8/10: 100%|██████████| 250/250 [00:01<00:00, 161.97batch/s, loss=0.0930]
# Epoch 8/10 - loss: 0.0821, val_loss: 0.3479
# Epoch 9/10: 100%|██████████| 250/250 [00:01<00:00, 170.09batch/s, loss=0.0670]
# Epoch 9/10 - loss: 0.0729, val_loss: 0.3989
# Epoch 10/10: 100%|██████████| 250/250 [00:01<00:00, 197.55batch/s, loss=0.0302]
# Epoch 10/10 - loss: 0.0679, val_loss: 0.4167
# Training took 13.86 seconds
# FFNN (1 hidden layer, 32 neurons) accuracy: 0.9230
#
# Training model with width=64
#
# Training FFNN (1 hidden layer, 64 neurons)...
# Epoch 1/10: 100%|██████████| 250/250 [00:03<00:00, 75.95batch/s, loss=0.3504]
# Epoch 1/10 - loss: 0.4403, val_loss: 0.3163
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 108.37batch/s, loss=0.2267]
# Epoch 2/10 - loss: 0.2146, val_loss: 0.2570
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 115.26batch/s, loss=0.0499]
# Epoch 3/10 - loss: 0.1603, val_loss: 0.2793
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 105.35batch/s, loss=0.0437]
# Epoch 4/10 - loss: 0.1187, val_loss: 0.2878
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 115.34batch/s, loss=0.2456]
# Epoch 5/10 - loss: 0.1029, val_loss: 0.3882
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 111.58batch/s, loss=0.0212]
# Epoch 6/10 - loss: 0.0799, val_loss: 0.3789
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 98.21batch/s, loss=0.0309]
# Epoch 7/10 - loss: 0.0724, val_loss: 0.3699
# Epoch 8/10: 100%|██████████| 250/250 [00:01<00:00, 135.49batch/s, loss=0.1106]
# Epoch 8/10 - loss: 0.0700, val_loss: 0.3852
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 97.15batch/s, loss=0.0128]
# Epoch 9/10 - loss: 0.0548, val_loss: 0.4161
# Epoch 10/10: 100%|██████████| 250/250 [00:01<00:00, 125.15batch/s, loss=0.0903]
# Epoch 10/10 - loss: 0.0544, val_loss: 0.4340
# Training took 23.77 seconds
# FFNN (1 hidden layer, 64 neurons) accuracy: 0.9340
#
# Training model with width=128
#
# Training FFNN (1 hidden layer, 128 neurons)...
# Epoch 1/10: 100%|██████████| 250/250 [00:11<00:00, 21.89batch/s, loss=0.2735]
# Epoch 1/10 - loss: 0.4208, val_loss: 0.2444
# Epoch 2/10: 100%|██████████| 250/250 [00:09<00:00, 27.31batch/s, loss=0.6005]
# Epoch 2/10 - loss: 0.1965, val_loss: 0.2540
# Epoch 3/10: 100%|██████████| 250/250 [00:07<00:00, 33.48batch/s, loss=0.0469]
# Epoch 3/10 - loss: 0.1490, val_loss: 0.2520
# Epoch 4/10: 100%|██████████| 250/250 [00:09<00:00, 25.15batch/s, loss=0.0216]
# Epoch 4/10 - loss: 0.1168, val_loss: 0.2604
# Epoch 5/10: 100%|██████████| 250/250 [00:11<00:00, 21.80batch/s, loss=0.0143]
# Epoch 5/10 - loss: 0.0996, val_loss: 0.2692
# Epoch 6/10: 100%|██████████| 250/250 [00:11<00:00, 22.32batch/s, loss=0.1062]
# Epoch 6/10 - loss: 0.0814, val_loss: 0.2806
# Epoch 7/10: 100%|██████████| 250/250 [00:10<00:00, 23.38batch/s, loss=0.1542]
# Epoch 7/10 - loss: 0.0568, val_loss: 0.3586
# Epoch 8/10: 100%|██████████| 250/250 [00:11<00:00, 22.34batch/s, loss=0.1532]
# Epoch 8/10 - loss: 0.0678, val_loss: 0.3558
# Epoch 9/10: 100%|██████████| 250/250 [00:11<00:00, 22.06batch/s, loss=0.1262]
# Epoch 9/10 - loss: 0.0566, val_loss: 0.4206
# Epoch 10/10: 100%|██████████| 250/250 [00:11<00:00, 22.34batch/s, loss=0.0103]
# Epoch 10/10 - loss: 0.0551, val_loss: 0.3998
# Training took 105.36 seconds
# FFNN (1 hidden layer, 128 neurons) accuracy: 0.9420

# %% [markdown]
# ## Experiment 2: Varying Depth

# %%
# Testing 3 different depths with fixed width
depths = [1, 2, 3]  # Number of hidden layers
depth_histories = []
depth_accuracies = []

for depth in depths:
    layer_sizes = [input_size] + [64] * depth + [output_size]
    activations = [ReLU()] * depth + [Softmax()]

    model_name = f"FFNN ({depth} hidden layers, 64 neurons each)"
    print(f"\nTraining model with depth={depth}")

    model = FFNN(
        layer_sizes=layer_sizes,
        activations=activations,
        loss=CategoricalCrossEntropy(),
    )

    history, accuracy, _, _ = train_and_evaluate(
        model,
        X_train,
        X_test,
        y_train_onehot,
        y_test,
        y_test_onehot,
        epochs=epochs,
        batch_size=batch_size,
        learning_rate=learning_rate,
        model_name=model_name,
    )

    depth_histories.append(history)
    depth_accuracies.append(accuracy)

# Plot depth experiment results
plt.figure(figsize=(12, 6))
for i, depth in enumerate(depths):
    plt.plot(depth_histories[i]["loss"], label=f"Depth={depth}")

plt.title("Training Loss vs. Depth (Width=64)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.savefig("../../out/depth_comparison_loss.png")

# Bar chart of accuracies
plt.figure(figsize=(10, 6))
plt.bar([str(d) for d in depths], depth_accuracies, color="lightgreen")
plt.title("Test Accuracy vs. Depth (Width=64)")
plt.xlabel("Depth (hidden layers)")
plt.ylabel("Accuracy")
plt.ylim([0.9 * min(depth_accuracies), 1.0])  # Adjust y-axis for better visibility
for i, v in enumerate(depth_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha="center")
plt.savefig("../../out/depth_comparison_accuracy.png")
# Out:
# Training model with depth=1
#
# Training FFNN (1 hidden layers, 64 neurons each)...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 115.44batch/s, loss=0.1609]
# Epoch 1/10 - loss: 0.4432, val_loss: 0.2712
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 116.71batch/s, loss=0.8120]
# Epoch 2/10 - loss: 0.2079, val_loss: 0.3048
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 103.96batch/s, loss=0.2291]
# Epoch 3/10 - loss: 0.1523, val_loss: 0.2847
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 104.17batch/s, loss=0.0834]
# Epoch 4/10 - loss: 0.1231, val_loss: 0.3150
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 105.38batch/s, loss=0.1543]
# Epoch 5/10 - loss: 0.0842, val_loss: 0.4001
# Epoch 6/10: 100%|██████████| 250/250 [00:03<00:00, 80.89batch/s, loss=0.0004]
# Epoch 6/10 - loss: 0.0885, val_loss: 0.3264
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 107.45batch/s, loss=0.1408]
# Epoch 7/10 - loss: 0.0751, val_loss: 0.4984
# Epoch 8/10: 100%|██████████| 250/250 [00:02<00:00, 89.22batch/s, loss=0.1472]
# Epoch 8/10 - loss: 0.0704, val_loss: 0.3616
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 93.87batch/s, loss=0.1190]
# Epoch 9/10 - loss: 0.0485, val_loss: 0.3923
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 105.56batch/s, loss=0.0421]
# Epoch 10/10 - loss: 0.0612, val_loss: 0.4570
# Training took 25.01 seconds
# FFNN (1 hidden layers, 64 neurons each) accuracy: 0.9355
#
# Training model with depth=2
#
# Training FFNN (2 hidden layers, 64 neurons each)...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 86.34batch/s, loss=0.2019]
# Epoch 1/10 - loss: 0.4763, val_loss: 0.3221
# Epoch 2/10: 100%|██████████| 250/250 [00:03<00:00, 73.99batch/s, loss=0.0169]
# Epoch 2/10 - loss: 0.2510, val_loss: 0.3629
# Epoch 3/10: 100%|██████████| 250/250 [00:04<00:00, 58.22batch/s, loss=0.3462]
# Epoch 3/10 - loss: 0.1918, val_loss: 0.3189
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 84.68batch/s, loss=0.0156]
# Epoch 4/10 - loss: 0.1551, val_loss: 0.3395
# Epoch 5/10: 100%|██████████| 250/250 [00:01<00:00, 147.71batch/s, loss=0.1595]
# Epoch 5/10 - loss: 0.1598, val_loss: 0.2963
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 103.74batch/s, loss=0.5469]
# Epoch 6/10 - loss: 0.1375, val_loss: 0.3177
# Epoch 7/10: 100%|██████████| 250/250 [00:03<00:00, 82.02batch/s, loss=0.0667]
# Epoch 7/10 - loss: 0.1312, val_loss: 0.3612
# Epoch 8/10: 100%|██████████| 250/250 [00:02<00:00, 106.72batch/s, loss=0.4435]
# Epoch 8/10 - loss: 0.1105, val_loss: 0.4284
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 109.12batch/s, loss=0.3236]
# Epoch 9/10 - loss: 0.1143, val_loss: 0.3512
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 124.47batch/s, loss=0.0108]
# Epoch 10/10 - loss: 0.0975, val_loss: 0.5081
# Training took 27.59 seconds
# FFNN (2 hidden layers, 64 neurons each) accuracy: 0.9175
#
# Training model with depth=3
#
# Training FFNN (3 hidden layers, 64 neurons each)...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 86.81batch/s, loss=0.1457]
# Epoch 1/10 - loss: 0.5802, val_loss: 0.3944
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 84.72batch/s, loss=0.4705]
# Epoch 2/10 - loss: 0.2977, val_loss: 0.3477
# Epoch 3/10: 100%|██████████| 250/250 [00:03<00:00, 67.70batch/s, loss=0.2139]
# Epoch 3/10 - loss: 0.2408, val_loss: 0.2622
# Epoch 4/10: 100%|██████████| 250/250 [00:03<00:00, 76.47batch/s, loss=0.1153]
# Epoch 4/10 - loss: 0.2219, val_loss: 0.3225
# Epoch 5/10: 100%|██████████| 250/250 [00:03<00:00, 69.78batch/s, loss=0.1843]
# Epoch 5/10 - loss: 0.1568, val_loss: 0.3465
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 93.89batch/s, loss=0.2169]
# Epoch 6/10 - loss: 0.1609, val_loss: 0.3340
# Epoch 7/10: 100%|██████████| 250/250 [00:01<00:00, 142.95batch/s, loss=0.0149]
# Epoch 7/10 - loss: 0.1694, val_loss: 0.3302
# Epoch 8/10: 100%|██████████| 250/250 [00:01<00:00, 154.93batch/s, loss=0.2666]
# Epoch 8/10 - loss: 0.1440, val_loss: 0.3186
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 117.60batch/s, loss=0.0316]
# Epoch 9/10 - loss: 0.1484, val_loss: 0.3948
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 117.70batch/s, loss=0.3681]
# Epoch 10/10 - loss: 0.1367, val_loss: 0.4628
# Training took 26.95 seconds
# FFNN (3 hidden layers, 64 neurons each) accuracy: 0.9160

# %% [markdown]
# ## Comparison Analysis

# %%
print("\nWIDTH EXPERIMENT RESULTS:")
for i, width in enumerate(widths):
    print(f"Width={width}: Accuracy={width_accuracies[i]:.4f}")

print("\nDEPTH EXPERIMENT RESULTS:")
for i, depth in enumerate(depths):
    print(f"Depth={depth}: Accuracy={depth_accuracies[i]:.4f}")

# Plot combined analysis
plt.figure(figsize=(14, 7))

# Plot width comparison
plt.subplot(1, 2, 1)
bars1 = plt.bar([str(w) for w in widths], width_accuracies, color="skyblue")
plt.title("Accuracy vs. Width (1 Hidden Layer)")
plt.xlabel("Width (neurons)")
plt.ylabel("Accuracy")
plt.ylim([0.9 * min(width_accuracies), 1.0])
for bar in bars1:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2.0,
        height + 0.005,
        f"{height:.4f}",
        ha="center",
        va="bottom",
    )

# Plot depth comparison
plt.subplot(1, 2, 2)
bars2 = plt.bar([str(d) for d in depths], depth_accuracies, color="lightgreen")
plt.title("Accuracy vs. Depth (Width=64)")
plt.xlabel("Depth (hidden layers)")
plt.ylabel("Accuracy")
plt.ylim([0.9 * min(depth_accuracies), 1.0])
for bar in bars2:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2.0,
        height + 0.005,
        f"{height:.4f}",
        ha="center",
        va="bottom",
    )

plt.tight_layout()
plt.savefig("../../out/depth_width_comparison.png")
# Out:
# WIDTH EXPERIMENT RESULTS:
# Width=32: Accuracy=0.9230
# Width=64: Accuracy=0.9340
# Width=128: Accuracy=0.9420
#
# DEPTH EXPERIMENT RESULTS:
# Depth=1: Accuracy=0.9355
# Depth=2: Accuracy=0.9175
# Depth=3: Accuracy=0.9160
