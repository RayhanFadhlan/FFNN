# %% [markdown]
# # Pengujian Pengaruh Learning Rate pada FFNN

# %% [markdown]
# Pengujian bertujuan untuk menganalisis pengaruh learning rate pada training FFNN.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# Add parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %load_ext autoreload
# %autoreload 2

from model import FFNN
from activation import ReLU, Softmax
from loss import CategoricalCrossEntropy
from utils import load_mnist_data, train_and_evaluate

# Create out dir
os.makedirs("../../out", exist_ok=True)

# %%
# Load MNIST dataset
X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data()

input_size = X_train.shape[1]  # 784 for MNIST
output_size = y_train_onehot.shape[1]  # 10 for MNIST
hidden_size = 64  # Fixed hidden layer size for all experiments

# Experiment configurations
epochs = 10
batch_size = 32

# Testing different learning rates
learning_rates = [0.001, 0.01, 0.1]
lr_histories = []
lr_accuracies = []
trained_models = []

for lr in learning_rates:
    model_name = f"FFNN with learning rate={lr}"
    print(f"\nTraining model with learning rate={lr}")
    
    model = FFNN(
        layer_sizes=[input_size, hidden_size, output_size],
        activations=[ReLU(), Softmax()],
        loss=CategoricalCrossEntropy()
    )
    
    history, accuracy, _, trained_model = train_and_evaluate(
        model, X_train, X_test, y_train_onehot, y_test, y_test_onehot,
        epochs=epochs, batch_size=batch_size, learning_rate=lr,
        model_name=model_name
    )
    
    lr_histories.append(history)
    lr_accuracies.append(accuracy)
    trained_models.append(trained_model)


# Plot loss curves for all learning rates
plt.figure(figsize=(12, 6))
for i, lr in enumerate(learning_rates):
    plt.plot(lr_histories[i]['loss'], label=f'LR={lr}')

plt.title('Training Loss Comparison of Different Learning Rates')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('../../out/learning_rate_comparison_loss.png')


# Bar chart of accuracies
plt.figure(figsize=(10, 6))
plt.bar([f'LR={lr}' for lr in learning_rates], lr_accuracies, color='skyblue')
plt.title('Test Accuracy Comparison of Different Learning Rates')
plt.xlabel('Learning Rate')
plt.ylabel('Accuracy')
plt.ylim([0.8, 1.0])  # Adjust y-axis for better visibility
for i, v in enumerate(lr_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha='center')
plt.savefig('../../out/learning_rate_comparison_accuracy.png')


for i, lr in enumerate(learning_rates):
    model = trained_models[i]
    
    # Plot weight distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Weight Distribution with Learning Rate = {lr}', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        weights = layer.weights.flatten()
        plt.hist(weights, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Weight Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/lr_{lr}_weight_dist.png')
    
    # Plot gradient distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Gradient Distribution with Learning Rate = {lr}', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        gradients = layer.weights_grad.flatten()
        plt.hist(gradients, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Gradient Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/lr_{lr}_gradient_dist.png')


print("\nACCURACY RESULTS:")
for i, lr in enumerate(learning_rates):
    print(f"Learning Rate = {lr}: {lr_accuracies[i]:.4f}")

# Best and worst learning rates
best_idx = np.argmax(lr_accuracies)
worst_idx = np.argmin(lr_accuracies)

print(f"\nBest performing: Learning Rate = {learning_rates[best_idx]} with accuracy {lr_accuracies[best_idx]:.4f}")
print(f"Worst performing: Learning Rate = {learning_rates[worst_idx]} with accuracy {lr_accuracies[worst_idx]:.4f}")
# Out:
# Loading MNIST dataset...
# Data loaded: X_train: (56000, 784), y_train: (56000,)
# Test data: X_test: (14000, 784), y_test: (14000,)
#
# Training model with learning rate=0.001
#
# Training FFNN with learning rate=0.001...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:05<00:00, 308.28batch/s, loss=0.2457]
# Epoch 1/10 - loss: 0.2877, val_loss: 0.1873
# Epoch 2/10: 100%|██████████| 1750/1750 [00:05<00:00, 301.93batch/s, loss=0.0637]
# Epoch 2/10 - loss: 0.1430, val_loss: 0.1420
# Epoch 3/10: 100%|██████████| 1750/1750 [00:05<00:00, 304.90batch/s, loss=0.4150]
# Epoch 3/10 - loss: 0.1052, val_loss: 0.1196
# Epoch 4/10: 100%|██████████| 1750/1750 [00:05<00:00, 324.65batch/s, loss=0.0704]
# Epoch 4/10 - loss: 0.0829, val_loss: 0.1064
# Epoch 5/10: 100%|██████████| 1750/1750 [00:05<00:00, 320.45batch/s, loss=0.0258]
# Epoch 5/10 - loss: 0.0691, val_loss: 0.1060
# Epoch 6/10: 100%|██████████| 1750/1750 [00:05<00:00, 314.14batch/s, loss=0.0626]
# Epoch 6/10 - loss: 0.0574, val_loss: 0.1016
# Epoch 7/10: 100%|██████████| 1750/1750 [00:05<00:00, 306.08batch/s, loss=0.0528]
# Epoch 7/10 - loss: 0.0501, val_loss: 0.1057
# Epoch 8/10: 100%|██████████| 1750/1750 [00:05<00:00, 313.93batch/s, loss=0.0016]
# Epoch 8/10 - loss: 0.0428, val_loss: 0.1004
# Epoch 9/10: 100%|██████████| 1750/1750 [00:05<00:00, 327.35batch/s, loss=0.0100]
# Epoch 9/10 - loss: 0.0370, val_loss: 0.1023
# Epoch 10/10: 100%|██████████| 1750/1750 [00:05<00:00, 317.88batch/s, loss=0.0312]
# Epoch 10/10 - loss: 0.0329, val_loss: 0.1039
# Training took 56.13 seconds
# FFNN with learning rate=0.001 accuracy: 0.9724
#
# Training model with learning rate=0.01
#
# Training FFNN with learning rate=0.01...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:05<00:00, 318.57batch/s, loss=0.2172]
# Epoch 1/10 - loss: 0.2531, val_loss: 0.2268
# Epoch 2/10: 100%|██████████| 1750/1750 [00:05<00:00, 313.49batch/s, loss=0.7956]
# Epoch 2/10 - loss: 0.1716, val_loss: 0.1890
# Epoch 3/10: 100%|██████████| 1750/1750 [00:05<00:00, 299.39batch/s, loss=0.2838]
# Epoch 3/10 - loss: 0.1490, val_loss: 0.2015
# Epoch 4/10: 100%|██████████| 1750/1750 [00:05<00:00, 309.59batch/s, loss=0.0026]
# Epoch 4/10 - loss: 0.1383, val_loss: 0.1816
# Epoch 5/10: 100%|██████████| 1750/1750 [00:05<00:00, 304.99batch/s, loss=0.2616]
# Epoch 5/10 - loss: 0.1269, val_loss: 0.2117
# Epoch 6/10: 100%|██████████| 1750/1750 [00:06<00:00, 267.34batch/s, loss=0.0320]
# Epoch 6/10 - loss: 0.1208, val_loss: 0.1897
# Epoch 7/10: 100%|██████████| 1750/1750 [00:05<00:00, 291.91batch/s, loss=0.1258]
# Epoch 7/10 - loss: 0.1160, val_loss: 0.2158
# Epoch 8/10: 100%|██████████| 1750/1750 [00:06<00:00, 288.25batch/s, loss=0.0125]
# Epoch 8/10 - loss: 0.1114, val_loss: 0.2232
# Epoch 9/10: 100%|██████████| 1750/1750 [00:05<00:00, 294.46batch/s, loss=0.0032]
# Epoch 9/10 - loss: 0.1058, val_loss: 0.2348
# Epoch 10/10: 100%|██████████| 1750/1750 [00:06<00:00, 279.02batch/s, loss=0.0619]
# Epoch 10/10 - loss: 0.1013, val_loss: 0.2469
# Training took 59.54 seconds
# FFNN with learning rate=0.01 accuracy: 0.9596
#
# Training model with learning rate=0.1
#
# Training FFNN with learning rate=0.1...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:06<00:00, 282.90batch/s, loss=1.1102]
# Epoch 1/10 - loss: 1.1860, val_loss: 1.1426
# Epoch 2/10: 100%|██████████| 1750/1750 [00:06<00:00, 279.86batch/s, loss=0.6091]
# Epoch 2/10 - loss: 1.1317, val_loss: 1.0438
# Epoch 3/10: 100%|██████████| 1750/1750 [00:06<00:00, 276.08batch/s, loss=1.7267]
# Epoch 3/10 - loss: 1.1334, val_loss: 1.2631
# Epoch 4/10: 100%|██████████| 1750/1750 [00:06<00:00, 284.60batch/s, loss=0.4170]
# Epoch 4/10 - loss: 1.1425, val_loss: 1.1601
# Epoch 5/10: 100%|██████████| 1750/1750 [00:05<00:00, 311.69batch/s, loss=1.4341]
# Epoch 5/10 - loss: 1.1554, val_loss: 1.1847
# Epoch 6/10: 100%|██████████| 1750/1750 [00:05<00:00, 297.49batch/s, loss=4.0522]
# Epoch 6/10 - loss: 1.1812, val_loss: 1.0918
# Epoch 7/10: 100%|██████████| 1750/1750 [00:06<00:00, 263.11batch/s, loss=0.7809]
# Epoch 7/10 - loss: 1.1556, val_loss: 1.3104
# Epoch 8/10: 100%|██████████| 1750/1750 [00:06<00:00, 271.06batch/s, loss=0.6568]
# Epoch 8/10 - loss: 1.1680, val_loss: 1.1109
# Epoch 9/10: 100%|██████████| 1750/1750 [00:06<00:00, 259.36batch/s, loss=2.9433]
# Epoch 9/10 - loss: 1.1588, val_loss: 1.2039
# Epoch 10/10: 100%|██████████| 1750/1750 [00:06<00:00, 277.41batch/s, loss=1.0304]
# Epoch 10/10 - loss: 1.1914, val_loss: 1.2028
# Training took 62.98 seconds
# FFNN with learning rate=0.1 accuracy: 0.6598
#
# ACCURACY RESULTS:
# Learning Rate = 0.001: 0.9724
# Learning Rate = 0.01: 0.9596
# Learning Rate = 0.1: 0.6598
#
# Best performing: Learning Rate = 0.001 with accuracy 0.9724
# Worst performing: Learning Rate = 0.1 with accuracy 0.6598
