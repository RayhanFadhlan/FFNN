# %% [markdown]
# # Pengujian Pengaruh Learning Rate pada FFNN

# %% [markdown]
# Pengujian bertujuan untuk menganalisis pengaruh learning rate pada training FFNN.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# Add parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %load_ext autoreload
# %autoreload 2

from model import FFNN
from activation import ReLU, Softmax
from loss import CategoricalCrossEntropy
from utils import load_mnist_data, train_and_evaluate

# Create out dir
os.makedirs("../../out", exist_ok=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load MNIST dataset
X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data()

input_size = X_train.shape[1]  # 784 for MNIST
output_size = y_train_onehot.shape[1]  # 10 for MNIST
hidden_size = 64  # Fixed hidden layer size for all experiments

# Experiment configs
epochs = 10
batch_size = 32

# Test different learning rates
learning_rates = [0.001, 0.01, 0.1]
lr_histories = []
lr_accuracies = []
trained_models = []

for lr in learning_rates:
    model_name = f"FFNN with learning rate={lr}"
    print(f"\nTraining model with learning rate={lr}")

    model = FFNN(
        layer_sizes=[input_size, hidden_size, output_size],
        activations=[ReLU(), Softmax()],
        loss=CategoricalCrossEntropy()
    )

    history, accuracy, _, trained_model = train_and_evaluate(
        model, X_train, X_test, y_train_onehot, y_test, y_test_onehot,
        epochs=epochs, batch_size=batch_size, learning_rate=lr,
        model_name=model_name
    )

    lr_histories.append(history)
    lr_accuracies.append(accuracy)
    trained_models.append(trained_model)


# Plot loss curves for all learning rates
plt.figure(figsize=(12, 6))
for i, lr in enumerate(learning_rates):
    plt.plot(lr_histories[i]['loss'], label=f'LR={lr}')
    plt.plot(lr_histories[i]['val_loss'], label=f'validation {lr}')  
plt.title('Training Loss Comparison of Different Learning Rates')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('../../out/learning_rate_comparison_loss.png')


# Bar chart of accuracies
plt.figure(figsize=(10, 6))
plt.bar([f'LR={lr}' for lr in learning_rates], lr_accuracies, color='skyblue')
plt.title('Test Accuracy Comparison of Different Learning Rates')
plt.xlabel('Learning Rate')
plt.ylabel('Accuracy')
# plt.ylim([0.8, 1.0])
for i, v in enumerate(lr_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha='center')
plt.savefig('../../out/learning_rate_comparison_accuracy.png')


for i, lr in enumerate(learning_rates):
    model = trained_models[i]

    # Plot weight distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Weight Distribution with Learning Rate = {lr}', fontsize=16)

    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        weights = layer.weights.flatten()
        plt.hist(weights, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Weight Value')
        plt.ylabel('Frequency')

    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/lr_{lr}_weight_dist.png')

    # Plot gradient distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Gradient Distribution with Learning Rate = {lr}', fontsize=16)

    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        gradients = layer.weights_grad.flatten()
        plt.hist(gradients, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Gradient Value')
        plt.ylabel('Frequency')

    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/lr_{lr}_gradient_dist.png')


print("\nACCURACY RESULTS:")
for i, lr in enumerate(learning_rates):
    print(f"Learning Rate = {lr}: {lr_accuracies[i]:.4f}")

# Best and worst learning rates
best_idx = np.argmax(lr_accuracies)
worst_idx = np.argmin(lr_accuracies)

print(f"\nBest performing: Learning Rate = {learning_rates[best_idx]} with accuracy {lr_accuracies[best_idx]:.4f}")
print(f"Worst performing: Learning Rate = {learning_rates[worst_idx]} with accuracy {lr_accuracies[worst_idx]:.4f}")
# Out:
# Loading MNIST dataset...
# Data loaded: X_train: (56000, 784), y_train: (56000,)
# Test data: X_test: (14000, 784), y_test: (14000,)
#
# Training model with learning rate=0.001
#
# Training FFNN with learning rate=0.001...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:03<00:00, 468.49batch/s, loss=0.1126]
# Epoch 1/10 - loss: 0.2845, val_loss: 0.1781
# Epoch 2/10: 100%|██████████| 1750/1750 [00:03<00:00, 455.96batch/s, loss=0.1829]
# Epoch 2/10 - loss: 0.1398, val_loss: 0.1309
# Epoch 3/10: 100%|██████████| 1750/1750 [00:03<00:00, 480.33batch/s, loss=0.4230]
# Epoch 3/10 - loss: 0.0995, val_loss: 0.1209
# Epoch 4/10: 100%|██████████| 1750/1750 [00:03<00:00, 467.12batch/s, loss=0.0293]
# Epoch 4/10 - loss: 0.0783, val_loss: 0.1061
# Epoch 5/10: 100%|██████████| 1750/1750 [00:03<00:00, 470.25batch/s, loss=0.1675]
# Epoch 5/10 - loss: 0.0644, val_loss: 0.1165
# Epoch 6/10: 100%|██████████| 1750/1750 [00:03<00:00, 506.89batch/s, loss=0.0060]
# Epoch 6/10 - loss: 0.0536, val_loss: 0.1080
# Epoch 7/10: 100%|██████████| 1750/1750 [00:03<00:00, 490.61batch/s, loss=0.0468]
# Epoch 7/10 - loss: 0.0457, val_loss: 0.1056
# Epoch 8/10: 100%|██████████| 1750/1750 [00:03<00:00, 501.05batch/s, loss=0.0932]
# Epoch 8/10 - loss: 0.0395, val_loss: 0.0988
# Epoch 9/10: 100%|██████████| 1750/1750 [00:03<00:00, 485.43batch/s, loss=0.0034]
# Epoch 9/10 - loss: 0.0345, val_loss: 0.1006
# Epoch 10/10: 100%|██████████| 1750/1750 [00:03<00:00, 505.00batch/s, loss=0.0006]
# Epoch 10/10 - loss: 0.0296, val_loss: 0.0983
# Training took 36.53 seconds
# FFNN with learning rate=0.001 accuracy: 0.9731
#
# Training model with learning rate=0.01
#
# Training FFNN with learning rate=0.01...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:03<00:00, 511.24batch/s, loss=0.1073]
# Epoch 1/10 - loss: 0.2411, val_loss: 0.1953
# Epoch 2/10: 100%|██████████| 1750/1750 [00:03<00:00, 485.90batch/s, loss=1.0763]
# Epoch 2/10 - loss: 0.1646, val_loss: 0.1776
# Epoch 3/10: 100%|██████████| 1750/1750 [00:03<00:00, 484.54batch/s, loss=0.2501]
# Epoch 3/10 - loss: 0.1442, val_loss: 0.2108
# Epoch 4/10: 100%|██████████| 1750/1750 [00:03<00:00, 467.05batch/s, loss=0.1485]
# Epoch 4/10 - loss: 0.1308, val_loss: 0.1801
# Epoch 5/10: 100%|██████████| 1750/1750 [00:03<00:00, 467.75batch/s, loss=0.2934]
# Epoch 5/10 - loss: 0.1272, val_loss: 0.1939
# Epoch 6/10: 100%|██████████| 1750/1750 [00:04<00:00, 435.20batch/s, loss=0.3626]
# Epoch 6/10 - loss: 0.1150, val_loss: 0.2138
# Epoch 7/10: 100%|██████████| 1750/1750 [00:04<00:00, 406.78batch/s, loss=0.2646]
# Epoch 7/10 - loss: 0.1135, val_loss: 0.2630
# Epoch 8/10: 100%|██████████| 1750/1750 [00:04<00:00, 410.37batch/s, loss=0.0018]
# Epoch 8/10 - loss: 0.1079, val_loss: 0.2242
# Epoch 9/10: 100%|██████████| 1750/1750 [00:04<00:00, 419.40batch/s, loss=0.3254]
# Epoch 9/10 - loss: 0.1039, val_loss: 0.2464
# Epoch 10/10: 100%|██████████| 1750/1750 [00:04<00:00, 429.61batch/s, loss=0.0778]
# Epoch 10/10 - loss: 0.0989, val_loss: 0.2666
# Training took 39.22 seconds
# FFNN with learning rate=0.01 accuracy: 0.9623
#
# Training model with learning rate=0.1
#
# Training FFNN with learning rate=0.1...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:03<00:00, 446.52batch/s, loss=1.4726]
# Epoch 1/10 - loss: 1.6108, val_loss: 1.5274
# Epoch 2/10: 100%|██████████| 1750/1750 [00:04<00:00, 383.09batch/s, loss=0.9567]
# Epoch 2/10 - loss: 1.5025, val_loss: 1.4612
# Epoch 3/10: 100%|██████████| 1750/1750 [00:05<00:00, 342.69batch/s, loss=1.2138]
# Epoch 3/10 - loss: 1.4949, val_loss: 1.4617
# Epoch 4/10: 100%|██████████| 1750/1750 [00:04<00:00, 351.45batch/s, loss=1.1181]
# Epoch 4/10 - loss: 1.4915, val_loss: 1.4968
# Epoch 5/10: 100%|██████████| 1750/1750 [00:04<00:00, 354.01batch/s, loss=1.5762]
# Epoch 5/10 - loss: 1.5261, val_loss: 1.6198
# Epoch 6/10: 100%|██████████| 1750/1750 [00:05<00:00, 331.39batch/s, loss=0.9438]
# Epoch 6/10 - loss: 1.5543, val_loss: 1.6492
# Epoch 7/10: 100%|██████████| 1750/1750 [00:05<00:00, 347.46batch/s, loss=2.2855]
# Epoch 7/10 - loss: 1.5424, val_loss: 1.4789
# Epoch 8/10: 100%|██████████| 1750/1750 [00:05<00:00, 336.11batch/s, loss=1.6543]
# Epoch 8/10 - loss: 1.5308, val_loss: 1.5441
# Epoch 9/10: 100%|██████████| 1750/1750 [00:04<00:00, 359.30batch/s, loss=1.1028]
# Epoch 9/10 - loss: 1.5434, val_loss: 1.5350
# Epoch 10/10: 100%|██████████| 1750/1750 [00:04<00:00, 378.15batch/s, loss=2.2889]
# Epoch 10/10 - loss: 1.5680, val_loss: 1.6715
# Training took 48.85 seconds
# FFNN with learning rate=0.1 accuracy: 0.4494
#
# ACCURACY RESULTS:
# Learning Rate = 0.001: 0.9731
# Learning Rate = 0.01: 0.9623
# Learning Rate = 0.1: 0.4494
#
# Best performing: Learning Rate = 0.001 with accuracy 0.9731
# Worst performing: Learning Rate = 0.1 with accuracy 0.4494
