# %% [markdown]
# # Pengujian Pengaruh Fungsi Aktivasi Yang Berbeda

# %% [markdown]
# Pengujian bertujuan untuk menganalisis pengaruh fungsi aktivasi pada FFNN.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt


# Add parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %load_ext autoreload
# %autoreload 2

from model import FFNN
from activation import Linear, ReLU, Sigmoid, Tanh, Softmax, LeakyReLU, ELU
from loss import CategoricalCrossEntropy
from utils import load_mnist_data, train_and_evaluate

# Create out dir
os.makedirs("../../out", exist_ok=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load MNIST dataset
# X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data(subset_size=10000)
X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data()


input_size = X_train.shape[1]  # 784 for MNIST
output_size = y_train_onehot.shape[1]  # 10 for MNIST
hidden_size = 64  # Fixed hidden layer size for all experiments

# Experiment configurations
epochs = 10
batch_size = 32
learning_rate = 0.01
# Out:
# Loading MNIST dataset...
# Data loaded: X_train: (56000, 784), y_train: (56000,)
# Test data: X_test: (14000, 784), y_test: (14000,)

# %%
# Testing different activation functions
activations = [
    ("Linear", Linear()),
    ("ReLU", ReLU()),
    ("Sigmoid", Sigmoid()),
    ("Tanh", Tanh()),
    ("LeakyReLU", LeakyReLU(alpha=0.01)),
    ("ELU", ELU(alpha=1.0))
]

activation_histories = []
activation_accuracies = []
trained_models = []

for name, activation_func in activations:
    model_name = f"FFNN with {name} activation"
    print(f"\nTraining model with {name} activation function")
    
    model = FFNN(
        layer_sizes=[input_size, hidden_size, output_size],
        activations=[activation_func, Softmax()],
        loss=CategoricalCrossEntropy()
    )
    
    history, accuracy, _, trained_model = train_and_evaluate(
        model, X_train, X_test, y_train_onehot, y_test, y_test_onehot,
        epochs=epochs, batch_size=batch_size, learning_rate=learning_rate,
        model_name=model_name
    )
    
    activation_histories.append(history)
    activation_accuracies.append(accuracy)
    trained_models.append(trained_model)

# Plot loss curves for all activation functions
plt.figure(figsize=(14, 7))
for i, (name, _) in enumerate(activations):
    plt.plot(activation_histories[i]['loss'], label=f'{name}')

plt.title('Training Loss Comparison of Different Activation Functions')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('../../out/activation_comparison_loss.png')

# Bar chart of accuracies
plt.figure(figsize=(12, 6))
plt.bar([name for name, _ in activations], activation_accuracies, color='skyblue')
plt.title('Test Accuracy Comparison of Different Activation Functions')
plt.xlabel('Activation Function')
plt.ylabel('Accuracy')
plt.ylim([0.8, 1.0])
plt.xticks(rotation=45)
for i, v in enumerate(activation_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha='center')
plt.tight_layout()
plt.savefig('../../out/activation_comparison_accuracy.png')

# Plot weight and gradient distributions for each model
for i, (name, _) in enumerate(activations):
    model = trained_models[i]
    
    # Plot weight distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Weight Distribution with {name} Activation', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        weights = layer.weights.flatten()
        plt.hist(weights, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Weight Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/activation_{name}_weight_dist.png')
    
    # Plot gradient distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Gradient Distribution with {name} Activation', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        gradients = layer.weights_grad.flatten()
        plt.hist(gradients, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Gradient Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/activation_{name}_gradient_dist.png')


# Find best and worst performing activation functions
best_idx = np.argmax(activation_accuracies)
worst_idx = np.argmin(activation_accuracies)

print(f"\nBest performing: {activations[best_idx][0]} with accuracy {activation_accuracies[best_idx]:.4f}")
print(f"Worst performing: {activations[worst_idx][0]} with accuracy {activation_accuracies[worst_idx]:.4f}")
# Out:
# Training model with Linear activation function
#
# Training FFNN with Linear activation...
# Epoch 1/10:   0%|          | 0/1750 [00:00<?, ?batch/s]
# Epoch 1/10: 100%|██████████| 1750/1750 [00:17<00:00, 99.24batch/s, loss=0.1117]
# Epoch 1/10 - loss: 0.4749, val_loss: 0.3945
# Epoch 2/10: 100%|██████████| 1750/1750 [00:17<00:00, 100.54batch/s, loss=0.1450]
# Epoch 2/10 - loss: 0.4124, val_loss: 0.4413
# Epoch 3/10: 100%|██████████| 1750/1750 [00:19<00:00, 90.24batch/s, loss=0.4337]
# Epoch 3/10 - loss: 0.4005, val_loss: 0.4636
# Epoch 4/10: 100%|██████████| 1750/1750 [00:16<00:00, 105.90batch/s, loss=0.4508]
# Epoch 4/10 - loss: 0.4035, val_loss: 0.4814
# Epoch 5/10: 100%|██████████| 1750/1750 [00:12<00:00, 135.90batch/s, loss=0.2781]
# Epoch 5/10 - loss: 0.4029, val_loss: 0.4778
# Epoch 6/10: 100%|██████████| 1750/1750 [00:13<00:00, 126.46batch/s, loss=1.0986]
# Epoch 6/10 - loss: 0.3926, val_loss: 0.4478
# Epoch 7/10: 100%|██████████| 1750/1750 [00:14<00:00, 123.55batch/s, loss=0.1667]
# Epoch 7/10 - loss: 0.3938, val_loss: 0.4408
# Epoch 8/10: 100%|██████████| 1750/1750 [00:15<00:00, 116.04batch/s, loss=0.5022]
# Epoch 8/10 - loss: 0.3958, val_loss: 0.3983
# Epoch 9/10: 100%|██████████| 1750/1750 [00:15<00:00, 112.27batch/s, loss=0.3320]
# Epoch 9/10 - loss: 0.3960, val_loss: 0.4269
# Epoch 10/10: 100%|██████████| 1750/1750 [00:16<00:00, 105.30batch/s, loss=0.3174]
# Epoch 10/10 - loss: 0.3922, val_loss: 0.5218
# Training took 159.89 seconds
# FFNN with Linear activation accuracy: 0.8690
#
# Training model with ReLU activation function
#
# Training FFNN with ReLU activation...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:19<00:00, 87.66batch/s, loss=0.1262]
# Epoch 1/10 - loss: 0.2493, val_loss: 0.1896
# Epoch 2/10: 100%|██████████| 1750/1750 [00:26<00:00, 67.24batch/s, loss=0.0160]
# Epoch 2/10 - loss: 0.1671, val_loss: 0.1985
# Epoch 3/10: 100%|██████████| 1750/1750 [00:17<00:00, 100.50batch/s, loss=0.3495]
# Epoch 3/10 - loss: 0.1434, val_loss: 0.2171
# Epoch 4/10: 100%|██████████| 1750/1750 [00:17<00:00, 99.94batch/s, loss=0.0599]
# Epoch 4/10 - loss: 0.1347, val_loss: 0.2070
# Epoch 5/10: 100%|██████████| 1750/1750 [00:19<00:00, 88.44batch/s, loss=0.3802]
# Epoch 5/10 - loss: 0.1236, val_loss: 0.1920
# Epoch 6/10: 100%|██████████| 1750/1750 [00:21<00:00, 83.11batch/s, loss=0.0873]
# Epoch 6/10 - loss: 0.1197, val_loss: 0.2331
# Epoch 7/10: 100%|██████████| 1750/1750 [00:23<00:00, 73.95batch/s, loss=0.0086]
# Epoch 7/10 - loss: 0.1122, val_loss: 0.2274
# Epoch 8/10: 100%|██████████| 1750/1750 [00:23<00:00, 75.58batch/s, loss=0.0526]
# Epoch 8/10 - loss: 0.1078, val_loss: 0.2356
# Epoch 9/10: 100%|██████████| 1750/1750 [00:27<00:00, 63.73batch/s, loss=0.3345]
# Epoch 9/10 - loss: 0.1034, val_loss: 0.2520
# Epoch 10/10: 100%|██████████| 1750/1750 [00:26<00:00, 67.21batch/s, loss=0.0221]
# Epoch 10/10 - loss: 0.0999, val_loss: 0.2433
# Training took 223.03 seconds
# FFNN with ReLU activation accuracy: 0.9599
#
# Training model with Sigmoid activation function
#
# Training FFNN with Sigmoid activation...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:22<00:00, 78.21batch/s, loss=0.0339]
# Epoch 1/10 - loss: 0.2340, val_loss: 0.1549
# Epoch 2/10: 100%|██████████| 1750/1750 [00:20<00:00, 87.33batch/s, loss=0.2614]
# Epoch 2/10 - loss: 0.1303, val_loss: 0.1444
# Epoch 3/10: 100%|██████████| 1750/1750 [00:25<00:00, 69.17batch/s, loss=0.2350]
# Epoch 3/10 - loss: 0.1052, val_loss: 0.1336
# Epoch 4/10: 100%|██████████| 1750/1750 [00:20<00:00, 86.94batch/s, loss=0.1398]
# Epoch 4/10 - loss: 0.0933, val_loss: 0.1212
# Epoch 5/10: 100%|██████████| 1750/1750 [00:20<00:00, 86.77batch/s, loss=0.0394]
# Epoch 5/10 - loss: 0.0832, val_loss: 0.1308
# Epoch 6/10: 100%|██████████| 1750/1750 [00:16<00:00, 104.02batch/s, loss=0.0092]
# Epoch 6/10 - loss: 0.0773, val_loss: 0.1592
# Epoch 7/10: 100%|██████████| 1750/1750 [00:17<00:00, 101.01batch/s, loss=0.0215]
# Epoch 7/10 - loss: 0.0722, val_loss: 0.1336
# Epoch 8/10: 100%|██████████| 1750/1750 [00:18<00:00, 92.72batch/s, loss=0.0028]
# Epoch 8/10 - loss: 0.0669, val_loss: 0.1371
# Epoch 9/10: 100%|██████████| 1750/1750 [00:18<00:00, 96.07batch/s, loss=0.0587]
# Epoch 9/10 - loss: 0.0607, val_loss: 0.1497
# Epoch 10/10: 100%|██████████| 1750/1750 [00:17<00:00, 100.69batch/s, loss=0.0089]
# Epoch 10/10 - loss: 0.0601, val_loss: 0.1551
# Training took 197.78 seconds
# FFNN with Sigmoid activation accuracy: 0.9621
#
# Training model with Tanh activation function
#
# Training FFNN with Tanh activation...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:15<00:00, 112.07batch/s, loss=0.1148]
# Epoch 1/10 - loss: 0.2720, val_loss: 0.2121
# Epoch 2/10: 100%|██████████| 1750/1750 [00:16<00:00, 108.89batch/s, loss=0.0758]
# Epoch 2/10 - loss: 0.1890, val_loss: 0.1995
# Epoch 3/10: 100%|██████████| 1750/1750 [00:15<00:00, 115.96batch/s, loss=0.0605]
# Epoch 3/10 - loss: 0.1667, val_loss: 0.2065
# Epoch 4/10: 100%|██████████| 1750/1750 [00:15<00:00, 110.42batch/s, loss=0.0890]
# Epoch 4/10 - loss: 0.1487, val_loss: 0.1657
# Epoch 5/10: 100%|██████████| 1750/1750 [00:15<00:00, 113.97batch/s, loss=0.1059]
# Epoch 5/10 - loss: 0.1418, val_loss: 0.1722
# Epoch 6/10: 100%|██████████| 1750/1750 [00:20<00:00, 86.48batch/s, loss=0.0161]
# Epoch 6/10 - loss: 0.1302, val_loss: 0.1707
# Epoch 7/10: 100%|██████████| 1750/1750 [00:19<00:00, 90.81batch/s, loss=0.2270]
# Epoch 7/10 - loss: 0.1254, val_loss: 0.1572
# Epoch 8/10: 100%|██████████| 1750/1750 [00:17<00:00, 98.19batch/s, loss=0.0460]
# Epoch 8/10 - loss: 0.1168, val_loss: 0.1751
# Epoch 9/10: 100%|██████████| 1750/1750 [00:16<00:00, 103.57batch/s, loss=0.1258]
# Epoch 9/10 - loss: 0.1143, val_loss: 0.1590
# Epoch 10/10: 100%|██████████| 1750/1750 [00:17<00:00, 98.76batch/s, loss=0.0960]
# Epoch 10/10 - loss: 0.1136, val_loss: 0.1612
# Training took 171.37 seconds
# FFNN with Tanh activation accuracy: 0.9572
#
# Training model with LeakyReLU activation function
#
# Training FFNN with LeakyReLU activation...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:16<00:00, 107.70batch/s, loss=0.0171]
# Epoch 1/10 - loss: 0.2462, val_loss: 0.1913
# Epoch 2/10: 100%|██████████| 1750/1750 [00:18<00:00, 92.75batch/s, loss=0.1201]
# Epoch 2/10 - loss: 0.1646, val_loss: 0.1727
# Epoch 3/10: 100%|██████████| 1750/1750 [00:16<00:00, 104.46batch/s, loss=0.2232]
# Epoch 3/10 - loss: 0.1429, val_loss: 0.1913
# Epoch 4/10: 100%|██████████| 1750/1750 [00:17<00:00, 99.41batch/s, loss=0.0139]
# Epoch 4/10 - loss: 0.1288, val_loss: 0.1935
# Epoch 5/10: 100%|██████████| 1750/1750 [00:16<00:00, 103.93batch/s, loss=0.0039]
# Epoch 5/10 - loss: 0.1183, val_loss: 0.1870
# Epoch 6/10: 100%|██████████| 1750/1750 [00:16<00:00, 103.55batch/s, loss=0.0122]
# Epoch 6/10 - loss: 0.1106, val_loss: 0.2294
# Epoch 7/10: 100%|██████████| 1750/1750 [00:15<00:00, 115.88batch/s, loss=0.0012]
# Epoch 7/10 - loss: 0.1035, val_loss: 0.2040
# Epoch 8/10: 100%|██████████| 1750/1750 [00:16<00:00, 108.21batch/s, loss=0.0155]
# Epoch 8/10 - loss: 0.0989, val_loss: 0.2285
# Epoch 9/10: 100%|██████████| 1750/1750 [00:18<00:00, 95.56batch/s, loss=0.3085]
# Epoch 9/10 - loss: 0.0928, val_loss: 0.2485
# Epoch 10/10: 100%|██████████| 1750/1750 [00:16<00:00, 109.10batch/s, loss=0.0330]
# Epoch 10/10 - loss: 0.0928, val_loss: 0.2308
# Training took 169.85 seconds
# FFNN with LeakyReLU activation accuracy: 0.9646
#
# Training model with ELU activation function
#
# Training FFNN with ELU activation...
# Epoch 1/10: 100%|██████████| 1750/1750 [00:14<00:00, 118.87batch/s, loss=0.2355]
# Epoch 1/10 - loss: 0.2436, val_loss: 0.1978
# Epoch 2/10: 100%|██████████| 1750/1750 [00:14<00:00, 125.00batch/s, loss=0.1362]
# Epoch 2/10 - loss: 0.1566, val_loss: 0.1645
# Epoch 3/10: 100%|██████████| 1750/1750 [00:16<00:00, 103.62batch/s, loss=0.0713]
# Epoch 3/10 - loss: 0.1359, val_loss: 0.1872
# Epoch 4/10: 100%|██████████| 1750/1750 [00:17<00:00, 97.72batch/s, loss=0.2011]
# Epoch 4/10 - loss: 0.1227, val_loss: 0.1868
# Epoch 5/10: 100%|██████████| 1750/1750 [00:23<00:00, 73.88batch/s, loss=0.0042]
# Epoch 5/10 - loss: 0.1192, val_loss: 0.2057
# Epoch 6/10: 100%|██████████| 1750/1750 [00:17<00:00, 100.59batch/s, loss=0.0737]
# Epoch 6/10 - loss: 0.1103, val_loss: 0.2122
# Epoch 7/10: 100%|██████████| 1750/1750 [00:27<00:00, 64.78batch/s, loss=0.0277]
# Epoch 7/10 - loss: 0.1077, val_loss: 0.2551
# Epoch 8/10: 100%|██████████| 1750/1750 [00:42<00:00, 41.64batch/s, loss=0.1605]
# Epoch 8/10 - loss: 0.1074, val_loss: 0.3069
# Epoch 9/10: 100%|██████████| 1750/1750 [00:28<00:00, 60.41batch/s, loss=0.0009]
# Epoch 9/10 - loss: 0.1033, val_loss: 0.2744
# Epoch 10/10: 100%|██████████| 1750/1750 [00:19<00:00, 89.86batch/s, loss=0.0009]
# Epoch 10/10 - loss: 0.0981, val_loss: 0.2947
# Training took 223.47 seconds
# FFNN with ELU activation accuracy: 0.9676
#
# Best performing: ELU with accuracy 0.9676
# Worst performing: Linear with accuracy 0.8690
