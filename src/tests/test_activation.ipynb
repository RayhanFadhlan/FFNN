# %% [markdown]
# # Pengujian Pengaruh Fungsi Aktivasi Yang Berbeda

# %% [markdown]
# Pengujian bertujuan untuk menganalisis pengaruh fungsi aktivasi pada FFNN.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt


# Add parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %load_ext autoreload
# %autoreload 2

from model import FFNN
from activation import Linear, ReLU, Sigmoid, Tanh, Softmax, LeakyReLU, ELU
from loss import CategoricalCrossEntropy
from utils import load_mnist_data, train_and_evaluate

# Create out dir
os.makedirs("../../out", exist_ok=True)

# %%
# Load MNIST dataset
X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data(subset_size=10000)

input_size = X_train.shape[1]  # 784 for MNIST
output_size = y_train_onehot.shape[1]  # 10 for MNIST
hidden_size = 64  # Fixed hidden layer size for all experiments

# Experiment configurations
epochs = 10
batch_size = 32
learning_rate = 0.01
# Out:
# Loading MNIST dataset...
# Data loaded: X_train: (8000, 784), y_train: (8000,)
# Test data: X_test: (2000, 784), y_test: (2000,)

# %%
# Testing different activation functions
activations = [
    ("Linear", Linear()),
    ("ReLU", ReLU()),
    ("Sigmoid", Sigmoid()),
    ("Tanh", Tanh()),
    ("LeakyReLU", LeakyReLU(alpha=0.01)),
    ("ELU", ELU(alpha=1.0))
]

activation_histories = []
activation_accuracies = []
trained_models = []

for name, activation_func in activations:
    model_name = f"FFNN with {name} activation"
    print(f"\nTraining model with {name} activation function")
    
    model = FFNN(
        layer_sizes=[input_size, hidden_size, output_size],
        activations=[activation_func, Softmax()],
        loss=CategoricalCrossEntropy()
    )
    
    history, accuracy, _, trained_model = train_and_evaluate(
        model, X_train, X_test, y_train_onehot, y_test, y_test_onehot,
        epochs=epochs, batch_size=batch_size, learning_rate=learning_rate,
        model_name=model_name
    )
    
    activation_histories.append(history)
    activation_accuracies.append(accuracy)
    trained_models.append(trained_model)

# Plot loss curves for all activation functions
plt.figure(figsize=(14, 7))
for i, (name, _) in enumerate(activations):
    plt.plot(activation_histories[i]['loss'], label=f'{name}')

plt.title('Training Loss Comparison of Different Activation Functions')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('../../out/activation_comparison_loss.png')

# Bar chart of accuracies
plt.figure(figsize=(12, 6))
plt.bar([name for name, _ in activations], activation_accuracies, color='skyblue')
plt.title('Test Accuracy Comparison of Different Activation Functions')
plt.xlabel('Activation Function')
plt.ylabel('Accuracy')
plt.ylim([0.8, 1.0])  # Adjust y-axis for better visibility
plt.xticks(rotation=45)
for i, v in enumerate(activation_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha='center')
plt.tight_layout()
plt.savefig('../../out/activation_comparison_accuracy.png')

# Plot weight and gradient distributions for each model
for i, (name, _) in enumerate(activations):
    model = trained_models[i]
    
    # Plot weight distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Weight Distribution with {name} Activation', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        weights = layer.weights.flatten()
        plt.hist(weights, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Weight Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/activation_{name}_weight_dist.png')
    
    # Plot gradient distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Gradient Distribution with {name} Activation', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        gradients = layer.weights_grad.flatten()
        plt.hist(gradients, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Gradient Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/activation_{name}_gradient_dist.png')


# Find best and worst performing activation functions
best_idx = np.argmax(activation_accuracies)
worst_idx = np.argmin(activation_accuracies)

print(f"\nBest performing: {activations[best_idx][0]} with accuracy {activation_accuracies[best_idx]:.4f}")
print(f"Worst performing: {activations[worst_idx][0]} with accuracy {activation_accuracies[worst_idx]:.4f}")
# Out:
# Training model with Linear activation function
#
# Training FFNN with Linear activation...
# Epoch 1/10: 100%|██████████| 250/250 [00:01<00:00, 138.72batch/s, loss=0.4783]
# Epoch 1/10 - loss: 0.6538, val_loss: 0.4592
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 96.56batch/s, loss=0.4350]
# Epoch 2/10 - loss: 0.4424, val_loss: 0.4727
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 109.58batch/s, loss=0.4512]
# Epoch 3/10 - loss: 0.4158, val_loss: 0.4050
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 106.41batch/s, loss=0.6900]
# Epoch 4/10 - loss: 0.3642, val_loss: 0.4616
# Epoch 5/10: 100%|██████████| 250/250 [00:03<00:00, 62.89batch/s, loss=0.4842]
# Epoch 5/10 - loss: 0.3650, val_loss: 0.5449
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 92.63batch/s, loss=0.6059]
# Epoch 6/10 - loss: 0.3548, val_loss: 0.4594
# Epoch 7/10: 100%|██████████| 250/250 [00:03<00:00, 81.81batch/s, loss=0.3080]
# Epoch 7/10 - loss: 0.3293, val_loss: 0.5220
# Epoch 8/10: 100%|██████████| 250/250 [00:04<00:00, 53.98batch/s, loss=0.3296]
# Epoch 8/10 - loss: 0.3381, val_loss: 0.5001
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 104.52batch/s, loss=0.4790]
# Epoch 9/10 - loss: 0.3168, val_loss: 0.5111
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 93.00batch/s, loss=0.3322]
# Epoch 10/10 - loss: 0.3201, val_loss: 0.5052
# Training took 28.76 seconds
# FFNN with Linear activation accuracy: 0.8995
#
# Training model with ReLU activation function
#
# Training FFNN with ReLU activation...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 87.95batch/s, loss=0.1977]
# Epoch 1/10 - loss: 0.4236, val_loss: 0.2580
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 89.33batch/s, loss=0.3594]
# Epoch 2/10 - loss: 0.1962, val_loss: 0.2207
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 100.06batch/s, loss=0.3002]
# Epoch 3/10 - loss: 0.1388, val_loss: 0.2958
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 108.24batch/s, loss=0.0126]
# Epoch 4/10 - loss: 0.1260, val_loss: 0.2843
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 113.64batch/s, loss=0.0345]
# Epoch 5/10 - loss: 0.0988, val_loss: 0.3130
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 101.52batch/s, loss=0.1708]
# Epoch 6/10 - loss: 0.0794, val_loss: 0.3231
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 99.90batch/s, loss=0.1311]
# Epoch 7/10 - loss: 0.0776, val_loss: 0.2894
# Epoch 8/10: 100%|██████████| 250/250 [00:03<00:00, 81.55batch/s, loss=0.0826]
# Epoch 8/10 - loss: 0.0669, val_loss: 0.3284
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 104.83batch/s, loss=0.0198]
# Epoch 9/10 - loss: 0.0573, val_loss: 0.3380
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 106.23batch/s, loss=0.0243]
# Epoch 10/10 - loss: 0.0575, val_loss: 0.3749
# Training took 25.69 seconds
# FFNN with ReLU activation accuracy: 0.9370
#
# Training model with Sigmoid activation function
#
# Training FFNN with Sigmoid activation...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 94.74batch/s, loss=0.3189]
# Epoch 1/10 - loss: 0.4595, val_loss: 0.2756
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 111.88batch/s, loss=0.0528]
# Epoch 2/10 - loss: 0.2114, val_loss: 0.2512
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 102.54batch/s, loss=0.0453]
# Epoch 3/10 - loss: 0.1467, val_loss: 0.2028
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 113.06batch/s, loss=0.0579]
# Epoch 4/10 - loss: 0.1023, val_loss: 0.2094
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 105.45batch/s, loss=0.0818]
# Epoch 5/10 - loss: 0.0793, val_loss: 0.2136
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 101.07batch/s, loss=0.1995]
# Epoch 6/10 - loss: 0.0622, val_loss: 0.2032
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 114.99batch/s, loss=0.0303]
# Epoch 7/10 - loss: 0.0461, val_loss: 0.1954
# Epoch 8/10: 100%|██████████| 250/250 [00:03<00:00, 78.10batch/s, loss=0.0471]
# Epoch 8/10 - loss: 0.0378, val_loss: 0.2068
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 111.13batch/s, loss=0.0633]
# Epoch 9/10 - loss: 0.0310, val_loss: 0.2259
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 101.84batch/s, loss=0.0083]
# Epoch 10/10 - loss: 0.0342, val_loss: 0.2382
# Training took 24.71 seconds
# FFNN with Sigmoid activation accuracy: 0.9425
#
# Training model with Tanh activation function
#
# Training FFNN with Tanh activation...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 121.33batch/s, loss=0.5387]
# Epoch 1/10 - loss: 0.4353, val_loss: 0.2952
# Epoch 2/10: 100%|██████████| 250/250 [00:03<00:00, 80.83batch/s, loss=0.2207]
# Epoch 2/10 - loss: 0.2284, val_loss: 0.2634
# Epoch 3/10: 100%|██████████| 250/250 [00:03<00:00, 78.76batch/s, loss=0.0534]
# Epoch 3/10 - loss: 0.1839, val_loss: 0.2715
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 94.14batch/s, loss=0.1467]
# Epoch 4/10 - loss: 0.1563, val_loss: 0.2506
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 113.11batch/s, loss=0.0891]
# Epoch 5/10 - loss: 0.1401, val_loss: 0.2277
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 118.59batch/s, loss=0.2039]
# Epoch 6/10 - loss: 0.1264, val_loss: 0.2898
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 102.41batch/s, loss=0.0437]
# Epoch 7/10 - loss: 0.1108, val_loss: 0.2553
# Epoch 8/10: 100%|██████████| 250/250 [00:02<00:00, 101.75batch/s, loss=0.0377]
# Epoch 8/10 - loss: 0.1018, val_loss: 0.2651
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 124.14batch/s, loss=0.1756]
# Epoch 9/10 - loss: 0.0924, val_loss: 0.2255
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 99.99batch/s, loss=0.0187]
# Epoch 10/10 - loss: 0.0745, val_loss: 0.2470
# Training took 25.03 seconds
# FFNN with Tanh activation accuracy: 0.9425
#
# Training model with LeakyReLU activation function
#
# Training FFNN with LeakyReLU activation...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 111.58batch/s, loss=0.1592]
# Epoch 1/10 - loss: 0.4437, val_loss: 0.2583
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 109.93batch/s, loss=0.1048]
# Epoch 2/10 - loss: 0.2068, val_loss: 0.2522
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 118.17batch/s, loss=0.2402]
# Epoch 3/10 - loss: 0.1640, val_loss: 0.2564
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 97.62batch/s, loss=0.0026]
# Epoch 4/10 - loss: 0.1243, val_loss: 0.2770
# Epoch 5/10: 100%|██████████| 250/250 [00:03<00:00, 82.84batch/s, loss=0.1318]
# Epoch 5/10 - loss: 0.1101, val_loss: 0.3486
# Epoch 6/10: 100%|██████████| 250/250 [00:03<00:00, 63.79batch/s, loss=0.0228]
# Epoch 6/10 - loss: 0.0835, val_loss: 0.2986
# Epoch 7/10: 100%|██████████| 250/250 [00:03<00:00, 82.41batch/s, loss=0.0035]
# Epoch 7/10 - loss: 0.0730, val_loss: 0.2854
# Epoch 8/10: 100%|██████████| 250/250 [00:03<00:00, 72.72batch/s, loss=0.1495]
# Epoch 8/10 - loss: 0.0622, val_loss: 0.3182
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 101.72batch/s, loss=0.0035]
# Epoch 9/10 - loss: 0.0662, val_loss: 0.3042
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 98.44batch/s, loss=0.1858]
# Epoch 10/10 - loss: 0.0478, val_loss: 0.3651
# Training took 27.89 seconds
# FFNN with LeakyReLU activation accuracy: 0.9365
#
# Training model with ELU activation function
#
# Training FFNN with ELU activation...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 103.42batch/s, loss=0.3637]
# Epoch 1/10 - loss: 0.4458, val_loss: 0.2389
# Epoch 2/10: 100%|██████████| 250/250 [00:03<00:00, 77.21batch/s, loss=0.1043]
# Epoch 2/10 - loss: 0.2212, val_loss: 0.2334
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 84.07batch/s, loss=0.0290]
# Epoch 3/10 - loss: 0.1518, val_loss: 0.2259
# Epoch 4/10: 100%|██████████| 250/250 [00:03<00:00, 78.49batch/s, loss=0.1640]
# Epoch 4/10 - loss: 0.1142, val_loss: 0.2810
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 84.94batch/s, loss=0.0229]
# Epoch 5/10 - loss: 0.1032, val_loss: 0.3511
# Epoch 6/10: 100%|██████████| 250/250 [00:03<00:00, 79.67batch/s, loss=0.0145]
# Epoch 6/10 - loss: 0.0768, val_loss: 0.3443
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 84.21batch/s, loss=0.1713]
# Epoch 7/10 - loss: 0.0722, val_loss: 0.2901
# Epoch 8/10: 100%|██████████| 250/250 [00:02<00:00, 96.46batch/s, loss=0.0041]
# Epoch 8/10 - loss: 0.0587, val_loss: 0.3247
# Epoch 9/10: 100%|██████████| 250/250 [00:03<00:00, 82.10batch/s, loss=0.0757]
# Epoch 9/10 - loss: 0.0464, val_loss: 0.3764
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 94.07batch/s, loss=0.1147]
# Epoch 10/10 - loss: 0.0633, val_loss: 0.4357
# Training took 29.48 seconds
# FFNN with ELU activation accuracy: 0.9385
#
# Best performing: Sigmoid with accuracy 0.9425
# Worst performing: Linear with accuracy 0.8995
