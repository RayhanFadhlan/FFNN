# %% [markdown]
# # Pengujian Pengaruh Inisialisasi Bobot Pada Training FFNN

# %% [markdown]
# Pengujian ini bertujuan untuk menganalisis pengaruh inisialisasi nilai bobot pada training FFNN.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# Add parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %load_ext autoreload
# %autoreload 2

from model import FFNN
from activation import ReLU, Softmax
from loss import CategoricalCrossEntropy
from initializer import ZeroInitializer, UniformInitializer, NormalInitializer, XavierInitializer, HeInitializer
from layer import Layer
from utils import  train_and_evaluate, load_mnist_data

# Create out dir
os.makedirs("../../out", exist_ok=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def create_model_with_initializer(input_size, hidden_size, output_size, initializer):
    """
    Create a model with the specified initializer for all layers
    """
    model = FFNN(
        layer_sizes=[input_size, hidden_size, output_size],
        activations=[ReLU(), Softmax()],
        loss=CategoricalCrossEntropy()
    )
    
    # Replace the default initializers with the specified one
    model.layers = []
    for i in range(len(model.layer_sizes) - 1):
        model.layers.append(Layer(
            input_size=model.layer_sizes[i],
            output_size=model.layer_sizes[i + 1],
            activation=model.activations[i],
            weight_initializer=initializer
        ))
    
    return model

# %%
# Load MNIST dataset
X_train, X_test, y_train, y_test, y_train_onehot, y_test_onehot = load_mnist_data(subset_size=10000)

input_size = X_train.shape[1]  # 784 for MNIST
output_size = y_train_onehot.shape[1]  # 10 for MNIST
hidden_size = 64  # Fixed hidden layer size for all experiments

# Experiment config
epochs = 10
batch_size = 32
learning_rate = 0.01

# Testing different weight initialization methods
initializers = [
    ("Zero", ZeroInitializer()),
    ("Uniform", UniformInitializer(low=-0.1, high=0.1, seed=42)),
    ("Normal", NormalInitializer(mean=0.0, std=0.1, seed=42)),
    ("Xavier", XavierInitializer(seed=42)),
    ("He", HeInitializer(seed=42))
]

init_histories = []
init_accuracies = []
trained_models = []

for name, initializer in initializers:
    model_name = f"FFNN with {name} initialization"
    print(f"\nTraining model with {name} initialization")
    
    model = create_model_with_initializer(input_size, hidden_size, output_size, initializer)
    
    history, accuracy, _, trained_model = train_and_evaluate(
        model, X_train, X_test, y_train_onehot, y_test, y_test_onehot,
        epochs=epochs, batch_size=batch_size, learning_rate=learning_rate,
        model_name=model_name
    )
    
    init_histories.append(history)
    init_accuracies.append(accuracy)
    trained_models.append(trained_model)

# Plot loss curves for all initialization methods
plt.figure(figsize=(12, 6))
for i, (name, _) in enumerate(initializers):
    plt.plot(init_histories[i]['loss'], label=f'{name}')

plt.title('Training Loss Comparison of Different Weight Initialization Methods')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig('../../out/init_comparison_loss.png')

# Bar chart of accuracies
plt.figure(figsize=(12, 6))
plt.bar([name for name, _ in initializers], init_accuracies, color='skyblue')
plt.title('Test Accuracy Comparison of Different Weight Initialization Methods')
plt.xlabel('Initialization Method')
plt.ylabel('Accuracy')
plt.ylim([0, 1.0])
plt.xticks(rotation=45)
for i, v in enumerate(init_accuracies):
    plt.text(i, v + 0.01, f"{v:.4f}", ha='center')
plt.tight_layout()
plt.savefig('../../out/init_comparison_accuracy.png')

# Plot weight and gradient distributions for each model
for i, (name, _) in enumerate(initializers):
    model = trained_models[i]
    
    # Initial weight distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Initial Weight Distribution with {name} Initialization', fontsize=16)
    
    # Recreate a model with the same initializer to show initial weights
    initial_model = create_model_with_initializer(input_size, hidden_size, output_size, initializers[i][1])
    
    for j, layer in enumerate(initial_model.layers):
        plt.subplot(1, len(initial_model.layers), j+1)
        weights = layer.weights.flatten()
        plt.hist(weights, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Weight Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/init_{name}_initial_weight_dist.png')
    
    # Final weight distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Final Weight Distribution with {name} Initialization', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        weights = layer.weights.flatten()
        plt.hist(weights, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Weight Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/init_{name}_final_weight_dist.png')
    
    # Gradient distributions
    plt.figure(figsize=(12, 5))
    plt.suptitle(f'Gradient Distribution with {name} Initialization', fontsize=16)
    
    for j, layer in enumerate(model.layers):
        plt.subplot(1, len(model.layers), j+1)
        gradients = layer.weights_grad.flatten()
        plt.hist(gradients, bins=50, alpha=0.7)
        plt.title(f'Layer {j+1}')
        plt.xlabel('Gradient Value')
        plt.ylabel('Frequency')
        
    plt.tight_layout()
    plt.subplots_adjust(top=0.85)
    plt.savefig(f'../../out/init_{name}_gradient_dist.png')
# Out:
# Loading MNIST dataset...
# Data loaded: X_train: (8000, 784), y_train: (8000,)
# Test data: X_test: (2000, 784), y_test: (2000,)
#
# Training model with Zero initialization
#
# Training FFNN with Zero initialization...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 111.89batch/s, loss=2.3049]
# Epoch 1/10 - loss: 2.3024, val_loss: 2.3065
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 115.52batch/s, loss=2.2918]
# Epoch 2/10 - loss: 2.3011, val_loss: 2.3057
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 107.24batch/s, loss=2.2952]
# Epoch 3/10 - loss: 2.3019, val_loss: 2.3056
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 108.37batch/s, loss=2.3191]
# Epoch 4/10 - loss: 2.3022, val_loss: 2.3053
# Epoch 5/10: 100%|██████████| 250/250 [00:01<00:00, 125.70batch/s, loss=2.2986]
# Epoch 5/10 - loss: 2.3017, val_loss: 2.3043
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 94.22batch/s, loss=2.3015]
# Epoch 6/10 - loss: 2.3016, val_loss: 2.3057
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 111.03batch/s, loss=2.2933]
# Epoch 7/10 - loss: 2.3018, val_loss: 2.3045
# Epoch 8/10: 100%|██████████| 250/250 [00:04<00:00, 60.90batch/s, loss=2.2818]
# Epoch 8/10 - loss: 2.3018, val_loss: 2.3030
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 87.03batch/s, loss=2.2572]
# Epoch 9/10 - loss: 2.3018, val_loss: 2.3053
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 107.69batch/s, loss=2.2929]
# Epoch 10/10 - loss: 2.3019, val_loss: 2.3047
# Training took 25.45 seconds
# FFNN with Zero initialization accuracy: 0.1020
#
# Training model with Uniform initialization
#
# Training FFNN with Uniform initialization...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 98.42batch/s, loss=0.1602]
# Epoch 1/10 - loss: 0.4332, val_loss: 0.2860
# Epoch 2/10: 100%|██████████| 250/250 [00:02<00:00, 88.36batch/s, loss=0.0548]
# Epoch 2/10 - loss: 0.2045, val_loss: 0.2363
# Epoch 3/10: 100%|██████████| 250/250 [00:02<00:00, 96.62batch/s, loss=0.1051]
# Epoch 3/10 - loss: 0.1441, val_loss: 0.2247
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 93.75batch/s, loss=0.7244]
# Epoch 4/10 - loss: 0.1318, val_loss: 0.2907
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 107.64batch/s, loss=0.2221]
# Epoch 5/10 - loss: 0.0911, val_loss: 0.3237
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 113.32batch/s, loss=0.0538]
# Epoch 6/10 - loss: 0.0798, val_loss: 0.3885
# Epoch 7/10: 100%|██████████| 250/250 [00:02<00:00, 100.94batch/s, loss=0.0076]
# Epoch 7/10 - loss: 0.0712, val_loss: 0.3099
# Epoch 8/10: 100%|██████████| 250/250 [00:03<00:00, 83.27batch/s, loss=0.1028]
# Epoch 8/10 - loss: 0.0592, val_loss: 0.4346
# Epoch 9/10: 100%|██████████| 250/250 [00:02<00:00, 103.62batch/s, loss=0.0610]
# Epoch 9/10 - loss: 0.0569, val_loss: 0.3476
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 107.99batch/s, loss=0.0445]
# Epoch 10/10 - loss: 0.0504, val_loss: 0.3696
# Training took 25.58 seconds
# FFNN with Uniform initialization accuracy: 0.9415
#
# Training model with Normal initialization
#
# Training FFNN with Normal initialization...
# Epoch 1/10: 100%|██████████| 250/250 [00:02<00:00, 97.17batch/s, loss=0.3383]
# Epoch 1/10 - loss: 0.4317, val_loss: 0.2296
# Epoch 2/10: 100%|██████████| 250/250 [00:03<00:00, 82.67batch/s, loss=0.2894]
# Epoch 2/10 - loss: 0.1867, val_loss: 0.2664
# Epoch 3/10: 100%|██████████| 250/250 [00:03<00:00, 83.02batch/s, loss=0.1163]
# Epoch 3/10 - loss: 0.1436, val_loss: 0.2541
# Epoch 4/10: 100%|██████████| 250/250 [00:02<00:00, 92.06batch/s, loss=0.0125]
# Epoch 4/10 - loss: 0.1151, val_loss: 0.2587
# Epoch 5/10: 100%|██████████| 250/250 [00:02<00:00, 101.69batch/s, loss=0.2459]
# Epoch 5/10 - loss: 0.0949, val_loss: 0.3063
# Epoch 6/10: 100%|██████████| 250/250 [00:02<00:00, 115.30batch/s, loss=0.0040]
# Epoch 6/10 - loss: 0.0684, val_loss: 0.3144
# Epoch 7/10: 100%|██████████| 250/250 [00:05<00:00, 43.86batch/s, loss=0.0341]
# Epoch 7/10 - loss: 0.0762, val_loss: 0.2714
# Epoch 8/10: 100%|██████████| 250/250 [00:07<00:00, 31.38batch/s, loss=0.0217]
# Epoch 8/10 - loss: 0.0582, val_loss: 0.3768
# Epoch 9/10: 100%|██████████| 250/250 [00:06<00:00, 37.22batch/s, loss=0.0784]
# Epoch 9/10 - loss: 0.0513, val_loss: 0.3865
# Epoch 10/10: 100%|██████████| 250/250 [00:03<00:00, 75.09batch/s, loss=0.0136]
# Epoch 10/10 - loss: 0.0586, val_loss: 0.4484
# Training took 39.96 seconds
# FFNN with Normal initialization accuracy: 0.9305
#
# Training model with Xavier initialization
#
# Training FFNN with Xavier initialization...
# Epoch 1/10: 100%|██████████| 250/250 [00:04<00:00, 54.36batch/s, loss=0.1566]
# Epoch 1/10 - loss: 0.4326, val_loss: 0.2626
# Epoch 2/10: 100%|██████████| 250/250 [00:03<00:00, 77.96batch/s, loss=0.1372]
# Epoch 2/10 - loss: 0.2125, val_loss: 0.2366
# Epoch 3/10: 100%|██████████| 250/250 [00:03<00:00, 81.21batch/s, loss=0.1517]
# Epoch 3/10 - loss: 0.1615, val_loss: 0.2565
# Epoch 4/10: 100%|██████████| 250/250 [00:04<00:00, 51.54batch/s, loss=0.4445]
# Epoch 4/10 - loss: 0.1254, val_loss: 0.3148
# Epoch 5/10: 100%|██████████| 250/250 [00:06<00:00, 38.90batch/s, loss=0.1601]
# Epoch 5/10 - loss: 0.1000, val_loss: 0.4475
# Epoch 6/10: 100%|██████████| 250/250 [00:04<00:00, 57.16batch/s, loss=0.0631]
# Epoch 6/10 - loss: 0.0867, val_loss: 0.3213
# Epoch 7/10: 100%|██████████| 250/250 [00:07<00:00, 32.95batch/s, loss=0.0195]
# Epoch 7/10 - loss: 0.0743, val_loss: 0.3200
# Epoch 8/10: 100%|██████████| 250/250 [00:06<00:00, 41.65batch/s, loss=0.0072]
# Epoch 8/10 - loss: 0.0636, val_loss: 0.3492
# Epoch 9/10: 100%|██████████| 250/250 [00:06<00:00, 37.58batch/s, loss=0.1188]
# Epoch 9/10 - loss: 0.0505, val_loss: 0.4012
# Epoch 10/10: 100%|██████████| 250/250 [00:05<00:00, 41.70batch/s, loss=0.0023]
# Epoch 10/10 - loss: 0.0518, val_loss: 0.3647
# Training took 53.09 seconds
# FFNN with Xavier initialization accuracy: 0.9375
#
# Training model with He initialization
#
# Training FFNN with He initialization...
# Epoch 1/10: 100%|██████████| 250/250 [00:03<00:00, 67.08batch/s, loss=0.4273]
# Epoch 1/10 - loss: 0.4364, val_loss: 0.2799
# Epoch 2/10: 100%|██████████| 250/250 [00:05<00:00, 45.18batch/s, loss=0.1430]
# Epoch 2/10 - loss: 0.2116, val_loss: 0.2652
# Epoch 3/10: 100%|██████████| 250/250 [00:03<00:00, 65.68batch/s, loss=0.0378]
# Epoch 3/10 - loss: 0.1625, val_loss: 0.2305
# Epoch 4/10: 100%|██████████| 250/250 [00:07<00:00, 31.48batch/s, loss=0.0110]
# Epoch 4/10 - loss: 0.1297, val_loss: 0.2388
# Epoch 5/10: 100%|██████████| 250/250 [00:08<00:00, 30.09batch/s, loss=0.1623]
# Epoch 5/10 - loss: 0.0956, val_loss: 0.2805
# Epoch 6/10: 100%|██████████| 250/250 [00:08<00:00, 31.00batch/s, loss=0.0065]
# Epoch 6/10 - loss: 0.0875, val_loss: 0.3621
# Epoch 7/10: 100%|██████████| 250/250 [00:07<00:00, 32.46batch/s, loss=0.3016]
# Epoch 7/10 - loss: 0.0811, val_loss: 0.3436
# Epoch 8/10: 100%|██████████| 250/250 [00:06<00:00, 39.72batch/s, loss=0.1170]
# Epoch 8/10 - loss: 0.0632, val_loss: 0.3517
# Epoch 9/10: 100%|██████████| 250/250 [00:05<00:00, 44.82batch/s, loss=0.0014]
# Epoch 9/10 - loss: 0.0713, val_loss: 0.3775
# Epoch 10/10: 100%|██████████| 250/250 [00:02<00:00, 92.33batch/s, loss=0.1700]
# Epoch 10/10 - loss: 0.0512, val_loss: 0.4562
# Training took 59.96 seconds
# FFNN with He initialization accuracy: 0.9215

# %%
print("\nACCURACY RESULTS:")
for i, (name, _) in enumerate(initializers):
    print(f"{name} Initialization: {init_accuracies[i]:.4f}")

# Best and worst performing initialization methods
best_idx = np.argmax(init_accuracies)
worst_idx = np.argmin(init_accuracies)

print(f"\nBest performing: {initializers[best_idx][0]} with accuracy {init_accuracies[best_idx]:.4f}")
print(f"Worst performing: {initializers[worst_idx][0]} with accuracy {init_accuracies[worst_idx]:.4f}")
# Out:
# ACCURACY RESULTS:
# Zero Initialization: 0.1155
# Uniform Initialization: 0.9375
# Normal Initialization: 0.9485
# Xavier Initialization: 0.9270
# He Initialization: 0.9360
#
# Best performing: Normal with accuracy 0.9485
# Worst performing: Zero with accuracy 0.1155
